# %%
# !nvidia-smi
# !pip install -q condacolab
import condacolab
condacolab.install()
# runtime will restart automatically after this — that's normal
# Out:
# Fri Jul 17 08:48:40 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda create -y -n clrernet python=3.10
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 26.5.3
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/clrernet
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |           20_gnu          28 KB  conda-forge
#     bzip2-1.0.8                |       hda65f42_9         254 KB  conda-forge
#     ca-certificates-2026.6.17  |       hbd8a1cb_0         126 KB  conda-forge
#     ld_impl_linux-64-2.46.1    |default_hbd61a6d_102         728 KB  conda-forge
#     libexpat-2.8.1             |       hecca717_1          76 KB  conda-forge
# ...

# %%
# !conda run -n clrernet python --version
# Out:
# Python 3.10.20

# %%
# !nvidia-smi   # confirm driver/CUDA version shown top-right of output
# !conda run -n clrernet pip install torch==2.4.1 torchvision==0.19.1 torchaudio==2.4.1 --index-url https://download.pytorch.org/whl/cu121
# Out:
# Fri Jul 17 08:53:40 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !conda run -n clrernet pip uninstall -y torch torchvision torchaudio
# !conda run -n clrernet pip install torch==2.1.0 torchvision==0.16.0 torchaudio==2.1.0 --index-url https://download.pytorch.org/whl/cu121
# Out:
# Found existing installation: torch 2.4.1+cu121
# Uninstalling torch-2.4.1+cu121:
#   Successfully uninstalled torch-2.4.1+cu121
# Found existing installation: torchvision 0.19.1+cu121
# Uninstalling torchvision-0.19.1+cu121:
#   Successfully uninstalled torchvision-0.19.1+cu121
# Found existing installation: torchaudio 2.4.1+cu121
# Uninstalling torchaudio-2.4.1+cu121:
#   Successfully uninstalled torchaudio-2.4.1+cu121
#
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 GB 5.6 MB/s  0:00:53
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 129.4 MB/s  0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 114.0 MB/s  0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 64.8 MB/s  0:00:01
# ...
#   Attempting uninstall: triton
#     Found existing installation: triton 3.0.0
#     Uninstalling triton-3.0.0:
#       Successfully uninstalled triton-3.0.0
#
# ...

# %%
# !conda run -n clrernet pip install "numpy<2"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 133.1 MB/s  0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# ...
#
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 5.0.0.93 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.

# %%
# !conda run -n clrernet python -c "import torch; print(torch.__version__, torch.cuda.is_available())"
# Out:
# 2.1.0+cu121 True

# %%
# !conda run -n clrernet pip uninstall -y mmcv mmengine mmdet
# !conda run -n clrernet mim install mmengine
# !conda run -n clrernet mim install "mmcv>=2.0.0,<2.2.0"
# !conda run -n clrernet mim install "mmdet>=3.0.0,<3.4.0"
# Out:
# Found existing installation: mmengine 0.10.7
# Uninstalling mmengine-0.10.7:
#   Successfully uninstalled mmengine-0.10.7
# Found existing installation: mmdet 3.3.0
# Uninstalling mmdet-3.3.0:
#   Successfully uninstalled mmdet-3.3.0
#
# WARNING: Skipping mmcv as it is not installed.
#
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# ...
#   Using cached mmengine-0.10.7-py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# ...
# Using cached mmengine-0.10.7-py3-none-any.whl (452 kB)
# Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#
# ...
#
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# ...

# %%
# !conda run -n clrernet pip install "numpy<2"
# Out:
# ...
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# ...
#
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 5.0.0.93 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.

# %%
# !conda run -n clrernet python -c "import torch, mmcv, mmengine, mmdet; print(torch.__version__, torch.cuda.is_available()); print(mmengine.__version__, mmcv.__version__, mmdet.__version__)"
# Out:
# 2.1.0+cu121 True
# 0.10.7 2.1.0 3.3.0

# %%
# !git clone https://github.com/hirotomusiker/CLRerNet.git
# %cd CLRerNet
# Out:
# Cloning into 'CLRerNet'...
# remote: Enumerating objects: 659, done.
# remote: Counting objects: 100% (195/195), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 659 (delta 148), reused 130 (delta 130), pack-reused 464 (from 2)
# Receiving objects: 100% (659/659), 1.46 MiB | 8.04 MiB/s, done.
# Resolving deltas: 100% (275/275), done.
# /content/CLRerNet

# %%
# !conda run -n clrernet pip install -r requirements.txt
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> No available output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'albumentations' when getting requirements to build wheel
#
# ERROR conda.cli.main_run:execute(125): `conda run pip install -r requirements.txt` failed. (See above for error)

# %%
# !sed -i 's/albumentations==0.4.6/albumentations>=1.3.0,<1.5.0/' requirements.txt
# !cat requirements.txt
# Out:
# albumentations>=1.3.0,<1.5.0
# p_tqdm==1.4.2
# pytest
# pytest-cov
# tensorboard
# yapf==0.40.1

# %%
# !conda run -n clrernet pip install "numpy<2"

# %%
# !conda run -n clrernet pip install -r requirements.txt
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 84.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 125.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 128.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 MB 52.4 MB/s  0:00:01
# Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 96.3 MB/s  0:00:00
# ...

# %%
# !conda run -n clrernet python -c "import torch, mmcv, mmengine, mmdet, albumentations; print('OK')"
# Out:
# OK
#
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<string>", line 1, in <module>
#   File "/usr/local/envs/clrernet/lib/python3.10/site-packages/torch/__init__.py", line 1382, in <module>
#     from .functional import *  # noqa: F403
#   File "/usr/local/envs/clrernet/lib/python3.10/site-packages/torch/functional.py", line 7, in <module>
#     import torch.nn.functional as F
#   File "/usr/local/envs/clrernet/lib/python3.10/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
# ...

# %%
# !conda run -n clrernet pip install "numpy<2"
# !conda run -n clrernet python -c "import torch, mmcv, mmengine, mmdet, albumentations; print('OK, no warnings should appear above this line')"
# Out:
# ...
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# ...
#
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 5.0.0.93 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 5.0.0.93 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
#
# OK, no warnings should appear above this line
#
# ...

# %%
# !conda run -n clrernet pip install "opencv-python<5" "opencv-python-headless<5"
# Out:
# ...
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 64.4 MB/s  0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 70.3 MB/s  0:00:00
# Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 5.0.0.93
#     Uninstalling opencv-python-headless-5.0.0.93:
#       Successfully uninstalled opencv-python-headless-5.0.0.93
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 5.0.0.93
#     Uninstalling opencv-python-5.0.0.93:
#       Successfully uninstalled opencv-python-5.0.0.93
#
# ...

# %%
# %%writefile /content/check_env.py
import numpy, cv2, torch, mmcv, mmengine, mmdet, albumentations
print('numpy', numpy.__version__)
print('cv2', cv2.__version__)
print('torch', torch.__version__, torch.cuda.is_available())
print('ALL IMPORTS OK')
# Out:
# Writing /content/check_env.py

# %%
# !conda run -n clrernet python /content/check_env.py
# Out:
# numpy 2.2.6
# cv2 4.13.0
# torch 2.1.0+cu121 True
# ALL IMPORTS OK
#
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/content/check_env.py", line 1, in <module>
#     import numpy, cv2, torch, mmcv, mmengine, mmdet, albumentations
#   File "/usr/local/envs/clrernet/lib/python3.10/site-packages/torch/__init__.py", line 1382, in <module>
#     from .functional import *  # noqa: F403
#   File "/usr/local/envs/clrernet/lib/python3.10/site-packages/torch/functional.py", line 7, in <module>
#     import torch.nn.functional as F
# ...

# %%
# !conda run -n clrernet pip install "numpy<2" --no-deps
# Out:
# ...
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# ...

# %%
# !conda run -n clrernet python /content/check_env.py
# Out:
# numpy 1.26.4
# cv2 4.13.0
# torch 2.1.0+cu121 True
# ALL IMPORTS OK
#
# /usr/local/envs/clrernet/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.24). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
# %cd /content/CLRerNet/libs/models/layers/nms
# !conda run -n clrernet python setup.py install
# %cd /content/CLRerNet
# Out:
# /content/CLRerNet/libs/models/layers/nms
# running install
# running bdist_egg
# running egg_info
# writing manifest file 'src/nms.egg-info/SOURCES.txt'
# running install_lib
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.10
# creating build/lib.linux-x86_64-3.10/nms
# copying src/nms/__init__.py -> build/lib.linux-x86_64-3.10/nms
# running build_ext
# creating build/temp.linux-x86_64-3.10
# creating build/temp.linux-x86_64-3.10/src
# ...

# %%
# %cd /content/CLRerNet
# !wget https://github.com/hirotomusiker/CLRerNet/releases/download/v0.1.0/clrernet_culane_dla34_ema.pth
# Out:
# /content/CLRerNet
# --2026-07-17 09:25:29--  https://github.com/hirotomusiker/CLRerNet/releases/download/v0.1.0/clrernet_culane_dla34_ema.pth
# Resolving github.com (github.com)... 140.82.116.3
# Connecting to github.com (github.com)|140.82.116.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !pwd
# !ls demo/demo.jpg configs/clrernet/culane/clrernet_culane_dla34_ema.py clrernet_culane_dla34_ema.pth
# Out:
# /content/CLRerNet
# clrernet_culane_dla34_ema.pth			      demo/demo.jpg
# configs/clrernet/culane/clrernet_culane_dla34_ema.py

# %%
# !bash -c "cd /content/CLRerNet && conda run -n clrernet python demo/image_demo.py demo/demo.jpg configs/clrernet/culane/clrernet_culane_dla34_ema.py clrernet_culane_dla34_ema.pth --out-file=result.png"
# Out:
# Traceback (most recent call last):
#   File "/content/CLRerNet/demo/image_demo.py", line 5, in <module>
#     from mmdet.apis import init_detector
#   File "/usr/local/envs/clrernet/lib/python3.10/site-packages/mmdet/apis/__init__.py", line 2, in <module>
#     from .det_inferencer import DetInferencer
#   File "/usr/local/envs/clrernet/lib/python3.10/site-packages/mmdet/apis/det_inferencer.py", line 22, in <module>
#     from mmdet.evaluation import INSTANCE_OFFSET
#   File "/usr/local/envs/clrernet/lib/python3.10/site-packages/mmdet/evaluation/__init__.py", line 2, in <module>
#     from .evaluator import *  # noqa: F401,F403
#   File "/usr/local/envs/clrernet/lib/python3.10/site-packages/mmdet/evaluation/evaluator/__init__.py", line 2, in <module>
#     from .multi_datasets_evaluator import MultiDatasetsEvaluator
#   File "/usr/local/envs/clrernet/lib/python3.10/site-packages/mmdet/evaluation/evaluator/multi_datasets_evaluator.py", line 12, in <module>
# ...

# %%
# !mkdir -p /content/CLRerNet/dataset/culane/list
# !touch /content/CLRerNet/dataset/culane/list/test.txt

# %%
import os
os.environ["MPLBACKEND"] = "Agg"
os.environ["PYTHONPATH"] = "/content/CLRerNet"

# !/usr/local/envs/clrernet/bin/python /content/CLRerNet/demo/image_demo.py /content/CLRerNet/demo/demo.jpg /content/CLRerNet/configs/clrernet/culane/clrernet_culane_dla34_ema.py /content/CLRerNet/clrernet_culane_dla34_ema.pth --out-file=/content/CLRerNet/result.png
# Out:
# /usr/local/envs/clrernet/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.24). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loads checkpoint by local backend from path: /content/CLRerNet/clrernet_culane_dla34_ema.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: bbox_head.loss_seg.criterion.weight, bbox_head.seg_decoder.conv.weight, bbox_head.seg_decoder.conv.bias
#
# /usr/local/envs/clrernet/lib/python3.10/site-packages/mmdet/apis/inference.py:90: UserWarning: dataset_meta or class names are not saved in the checkpoint's meta data, use COCO classes by default.
#   warnings.warn(
# 0 data are loaded
# ...

# %%
# !cat /content/CLRerNet/libs/datasets/pipelines/alaug.py
# Out:
# """
# Alaug interface for albumentations transformations.
# Adapted from:
# https://github.com/aliyun/conditional-lane-detection/blob/master/mmdet/datasets/pipelines/alaug.py
# """
#
# import collections
# import copy
#
# import albumentations as al
# import numpy as np
# from mmdet.registry import TRANSFORMS
#
#
# @TRANSFORMS.register_module()
# class Alaug(object):
#     def __init__(self, transforms):
#         assert isinstance(transforms, collections.abc.Sequence)
#         # init as None
#         self.__augmentor = None
#         # put transforms in a list
#         self.transforms = []
#         self.bbox_params = None
#         self.keypoint_params = None
#
#         for transform in transforms:
#             if isinstance(transform, dict):
#                 if transform['type'] == 'Compose':
#                     self.get_al_params(transform['params'])
#                 else:
#                     transform = self.build_transforms(transform)
# ...

# %%
patch_target = "/content/CLRerNet/libs/datasets/pipelines/alaug.py"

with open(patch_target, "r") as f:
    content = f.read()

old_block = """        aug = self.__augmentor(
            image=img,
            keypoints=keypoints_val,
            bboxes=bboxes,
            mask=masks,
            bbox_labels=bbox_labels,
        )"""

new_block = """        aug_kwargs = {"image": img, "mask": masks}
        if self.keypoint_params is not None:
            aug_kwargs["keypoints"] = keypoints_val
        if self.bbox_params is not None:
            aug_kwargs["bboxes"] = bboxes
            aug_kwargs["bbox_labels"] = bbox_labels
        aug = self.__augmentor(**aug_kwargs)"""

assert old_block in content, "Pattern not found — file may differ from expected"
content = content.replace(old_block, new_block)

with open(patch_target, "w") as f:
    f.write(content)

print("Patched successfully")
# Out:
# Patched successfully

# %%
patch_target = "/content/CLRerNet/libs/datasets/pipelines/alaug.py"

with open(patch_target, "r") as f:
    content = f.read()

old_block = '''        aug_kwargs = {"image": img, "mask": masks}
        if self.keypoint_params is not None:
            aug_kwargs["keypoints"] = keypoints_val
        if self.bbox_params is not None:
            aug_kwargs["bboxes"] = bboxes
            aug_kwargs["bbox_labels"] = bbox_labels
        aug = self.__augmentor(**aug_kwargs)'''

new_block = '''        aug_kwargs = {"image": img}
        if masks is not None:
            aug_kwargs["mask"] = masks
        if self.keypoint_params is not None:
            aug_kwargs["keypoints"] = keypoints_val
        if self.bbox_params is not None:
            aug_kwargs["bboxes"] = bboxes
            aug_kwargs["bbox_labels"] = bbox_labels
        aug = self.__augmentor(**aug_kwargs)'''

assert old_block in content, "Pattern not found — paste current file content again"
content = content.replace(old_block, new_block)

with open(patch_target, "w") as f:
    f.write(content)

print("Patched successfully")
# Out:
# Patched successfully

# %%
old_readback = "        if 'gt_masks' in data:\n            data['gt_masks'] = [np.array(aug['mask'])]"
new_readback = "        if 'gt_masks' in data and 'mask' in aug:\n            data['gt_masks'] = [np.array(aug['mask'])]"

with open(patch_target, "r") as f:
    content = f.read()
assert old_readback in content, "Readback pattern not found"
content = content.replace(old_readback, new_readback)
with open(patch_target, "w") as f:
    f.write(content)
print("Patched readback too")
# Out:
# Patched readback too

# %%
import os
os.environ["MPLBACKEND"] = "Agg"
os.environ["PYTHONPATH"] = "/content/CLRerNet"

# !/usr/local/envs/clrernet/bin/python /content/CLRerNet/demo/image_demo.py /content/CLRerNet/demo/demo.jpg /content/CLRerNet/configs/clrernet/culane/clrernet_culane_dla34_ema.py /content/CLRerNet/clrernet_culane_dla34_ema.pth --out-file=/content/CLRerNet/result.png
# Out:
# /usr/local/envs/clrernet/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.24). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loads checkpoint by local backend from path: /content/CLRerNet/clrernet_culane_dla34_ema.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: bbox_head.loss_seg.criterion.weight, bbox_head.seg_decoder.conv.weight, bbox_head.seg_decoder.conv.bias
#
# /usr/local/envs/clrernet/lib/python3.10/site-packages/mmdet/apis/inference.py:90: UserWarning: dataset_meta or class names are not saved in the checkpoint's meta data, use COCO classes by default.
#   warnings.warn(
# 0 data are loaded
# ...

# %%
# !ls -la /content/CLRerNet/result.png
# Out:
# -rw-r--r-- 1 root root 835730 Jul 17 09:36 /content/CLRerNet/result.png

# %%
from PIL import Image
Image.open("/content/CLRerNet/result.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1640x590>

# %%
# !cat /content/CLRerNet/demo/image_demo.py
# Out:
# # based on https://github.com/open-mmlab/mmdetection/blob/v2.28.0/demo/image_demo.py
# # Copyright (c) OpenMMLab. All rights reserved.
# from argparse import ArgumentParser
#
# from mmdet.apis import init_detector
#
# from libs.api.inference import inference_one_image
# from libs.utils.visualizer import visualize_lanes
#
#
# def parse_args():
#     parser = ArgumentParser()
#     parser.add_argument('img', help='Image file')
#     parser.add_argument('config', help='Config file')
#     parser.add_argument('checkpoint', help='Checkpoint file')
#     parser.add_argument('--out-file', default='result.png', help='Path to output file')
#     parser.add_argument('--device', default='cuda:0', help='Device used for inference')
#     parser.add_argument(
#         '--score-thr', type=float, default=0.3, help='bbox score threshold'
#     )
#     args = parser.parse_args()
#     return args
#
#
# def main(args):
#     # build the model from a config file and a checkpoint file
# ...

# %%
# !cat /content/CLRerNet/libs/api/inference.py
# Out:
# # modified based on:
# # https://github.com/open-mmlab/mmdetection/blob/v2.28.0/mmdet/apis/inference.py
# # Copyright (c) OpenMMLab. All rights reserved.
#
# import cv2
# import torch
#
# from libs.datasets.metrics.culane_metric import interp
# from libs.datasets.pipelines import Compose
#
#
# def inference_one_image(model, img_path):
#     """Inference on an image with the detector.
#     Args:
#         model (nn.Module): The loaded detector.
#         img_path (str): Image path.
#     Returns:
#         img (np.ndarray): Image data with shape (width, height, channel).
#         preds (List[np.ndarray]): Detected lanes.
#     """
#     img = cv2.imread(img_path)
#     ori_shape = img.shape
#     data = dict(
#         filename=img_path,
#         sub_img_name=None,
#         img=img,
#         gt_points=[],
#         id_classes=[],
#         id_instances=[],
#         img_shape=ori_shape,
#         ori_shape=ori_shape,
#     )
#
#     cfg = model.cfg
# ...

# %%
# !cat /content/CLRerNet/libs/utils/visualizer.py
# Out:
# import copy
# import numpy as np
# import cv2
#
# GT_COLOR = (255, 0, 0)
# PRED_HIT_COLOR = (0, 255, 0)
# PRED_MISS_COLOR = (0, 0, 255)
#
#
# def draw_lane(lane, img=None, img_shape=None, width=30, color=(255, 255, 255)):
#     """
#     Overlay lanes on the image.
#     Args:
#         lane (np.ndarray): N (x, y) coordinates from a single lane, shape (N, 2).
#         img (np.ndarray): Source image.
#         img_shape (tuple): Blank image shape used when img is None.
#         width (int): Lane thickness.
#         color (tuple): Lane color in BGR.
#     Returns:
#         img (np.ndarray): Output image.
#     """
#     if img is None:
#         img = np.zeros(img_shape, dtype=np.uint8)
#     lane = lane.astype(np.int32)
#     for p1, p2 in zip(lane[:-1], lane[1:]):
#         cv2.line(img, tuple(p1), tuple(p2), color, thickness=width)
#     return img
#
#
# def visualize_lanes(
#     src,
#     preds,
#     annos=list(),
#     pred_ious=None,
#     iou_thr=0.5,
# ...

# %%
# %%writefile /content/CLRerNet/demo/video_demo.py
from argparse import ArgumentParser

import cv2
import torch
from mmdet.apis import init_detector

from libs.datasets.metrics.culane_metric import interp
from libs.datasets.pipelines import Compose
from libs.utils.visualizer import visualize_lanes


def parse_args():
    parser = ArgumentParser()
    parser.add_argument('video', help='Input video file')
    parser.add_argument('config', help='Config file')
    parser.add_argument('checkpoint', help='Checkpoint file')
    parser.add_argument('--out-file', default='result.mp4', help='Path to output video')
    parser.add_argument('--device', default='cuda:0', help='Device used for inference')
    return parser.parse_args()


def get_prediction(lanes, ori_h, ori_w):
    preds = []
    for lane in lanes:
        lane = lane.cpu().numpy()
        xs = lane[:, 0]
        ys = lane[:, 1]
        valid_mask = (xs >= 0) & (xs < 1)
        xs = xs * ori_w
        lane_xs = xs[valid_mask]
        lane_ys = ys[valid_mask] * ori_h
        lane_xs, lane_ys = lane_xs[::-1], lane_ys[::-1]
        pred = [(x, y) for x, y in zip(lane_xs, lane_ys)]
        interp_pred = interp(pred, n=5)
        preds.append(interp_pred)
    return preds


def inference_one_frame(model, img, test_pipeline):
    ori_shape = img.shape
    data = dict(
        filename=None,
        sub_img_name=None,
        img=img,
        gt_points=[],
        id_classes=[],
        id_instances=[],
        img_shape=ori_shape,
        ori_shape=ori_shape,
    )
    data = test_pipeline(data)
    data_ = dict(
        inputs=[data["inputs"]],
        data_samples=[data["data_samples"]],
    )
    with torch.no_grad():
        results = model.test_step(data_)
    lanes = results[0]['lanes']
    preds = get_prediction(lanes, ori_shape[0], ori_shape[1])
    return preds


def main(args):
    model = init_detector(args.config, args.checkpoint, device=args.device)
    model.bbox_head.test_cfg.as_lanes = False
    cfg = model.cfg
    test_pipeline = Compose(cfg.test_dataloader.dataset.pipeline)

    cap = cv2.VideoCapture(args.video)
    if not cap.isOpened():
        raise RuntimeError(f"Could not open video: {args.video}")

    fps = cap.get(cv2.CAP_PROP_FPS) or 25
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    writer = cv2.VideoWriter(args.out_file, fourcc, fps, (width, height))

    frame_idx = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        preds = inference_one_frame(model, frame, test_pipeline)
        vis = visualize_lanes(frame, preds)
        writer.write(vis)
        frame_idx += 1
        if frame_idx % 20 == 0:
            print(f"Processed {frame_idx}/{total_frames} frames")

    cap.release()
    writer.release()
    print(f"Done. Saved to {args.out_file}")


if __name__ == '__main__':
    args = parse_args()
    main(args)
# Out:
# Writing /content/CLRerNet/demo/video_demo.py

# %%
import os
os.environ["MPLBACKEND"] = "Agg"
os.environ["PYTHONPATH"] = "/content/CLRerNet"

# !/usr/local/envs/clrernet/bin/python /content/CLRerNet/demo/video_demo.py /content/your_video.mp4 /content/CLRerNet/configs/clrernet/culane/clrernet_culane_dla34_ema.py /content/CLRerNet/clrernet_culane_dla34_ema.pth --out-file=/content/CLRerNet/result_video.mp4
# Out:
# /usr/local/envs/clrernet/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.24). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loads checkpoint by local backend from path: /content/CLRerNet/clrernet_culane_dla34_ema.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: bbox_head.loss_seg.criterion.weight, bbox_head.seg_decoder.conv.weight, bbox_head.seg_decoder.conv.bias
#
# /usr/local/envs/clrernet/lib/python3.10/site-packages/mmdet/apis/inference.py:90: UserWarning: dataset_meta or class names are not saved in the checkpoint's meta data, use COCO classes by default.
#   warnings.warn(
# 0 data are loaded
# ...

# %%
# %%writefile /content/CLRerNet/demo/video_demo.py
from argparse import ArgumentParser

import cv2
import torch
from mmdet.apis import init_detector

from libs.datasets.metrics.culane_metric import interp
from libs.datasets.pipelines import Compose
from libs.utils.visualizer import visualize_lanes


def parse_args():
    parser = ArgumentParser()
    parser.add_argument('video', help='Input video file')
    parser.add_argument('config', help='Config file')
    parser.add_argument('checkpoint', help='Checkpoint file')
    parser.add_argument('--out-file', default='result.mp4', help='Path to output video')
    parser.add_argument('--device', default='cuda:0', help='Device used for inference')
    parser.add_argument('--max-frames', type=int, default=0, help='Limit frames for quick testing (0 = no limit)')
    return parser.parse_args()


def get_prediction(lanes, ori_h, ori_w):
    preds = []
    for lane in lanes:
        lane = lane.cpu().numpy()
        xs = lane[:, 0]
        ys = lane[:, 1]
        valid_mask = (xs >= 0) & (xs < 1)
        xs = xs * ori_w
        lane_xs = xs[valid_mask]
        lane_ys = ys[valid_mask] * ori_h
        lane_xs, lane_ys = lane_xs[::-1], lane_ys[::-1]
        pred = [(x, y) for x, y in zip(lane_xs, lane_ys)]
        interp_pred = interp(pred, n=5)
        preds.append(interp_pred)
    return preds


def inference_one_frame(model, img, test_pipeline):
    ori_shape = img.shape
    data = dict(
        filename=None,
        sub_img_name=None,
        img=img,
        gt_points=[],
        id_classes=[],
        id_instances=[],
        img_shape=ori_shape,
        ori_shape=ori_shape,
    )
    data = test_pipeline(data)
    data_ = dict(
        inputs=[data["inputs"]],
        data_samples=[data["data_samples"]],
    )
    with torch.no_grad():
        results = model.test_step(data_)
    lanes = results[0]['lanes']
    preds = get_prediction(lanes, ori_shape[0], ori_shape[1])
    return preds


def main(args):
    model = init_detector(args.config, args.checkpoint, device=args.device)
    model.bbox_head.test_cfg.as_lanes = False
    cfg = model.cfg
    test_pipeline = Compose(cfg.test_dataloader.dataset.pipeline)

    cap = cv2.VideoCapture(args.video)
    if not cap.isOpened():
        raise RuntimeError(f"Could not open video: {args.video}")

    fps = cap.get(cv2.CAP_PROP_FPS) or 25
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"Video: {width}x{height}, {fps} fps, {total_frames} frames")

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    writer = cv2.VideoWriter(args.out_file, fourcc, fps, (width, height))

    frame_idx = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        preds = inference_one_frame(model, frame, test_pipeline)
        if frame_idx < 5:
            print(f"Frame {frame_idx}: {len(preds)} lanes detected")
            for i, p in enumerate(preds):
                print(f"  lane {i}: {len(p)} points, sample: {p[:2]}")
        vis = visualize_lanes(frame, preds)
        writer.write(vis)
        frame_idx += 1
        if args.max_frames and frame_idx >= args.max_frames:
            break
        if frame_idx % 20 == 0:
            print(f"Processed {frame_idx}/{total_frames} frames")

    cap.release()
    writer.release()
    print(f"Done. Saved to {args.out_file}")


if __name__ == '__main__':
    args = parse_args()
    main(args)
# Out:
# Overwriting /content/CLRerNet/demo/video_demo.py

# %%
import os
os.environ["MPLBACKEND"] = "Agg"
os.environ["PYTHONPATH"] = "/content/CLRerNet"

# !/usr/local/envs/clrernet/bin/python /content/CLRerNet/demo/video_demo.py /content/your_video.mp4 /content/CLRerNet/configs/clrernet/culane/clrernet_culane_dla34_ema.py /content/CLRerNet/clrernet_culane_dla34_ema.pth --out-file=/content/CLRerNet/result_test.mp4 --max-frames 10
# Out:
# /usr/local/envs/clrernet/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.24). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loads checkpoint by local backend from path: /content/CLRerNet/clrernet_culane_dla34_ema.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: bbox_head.loss_seg.criterion.weight, bbox_head.seg_decoder.conv.weight, bbox_head.seg_decoder.conv.bias
#
# /usr/local/envs/clrernet/lib/python3.10/site-packages/mmdet/apis/inference.py:90: UserWarning: dataset_meta or class names are not saved in the checkpoint's meta data, use COCO classes by default.
#   warnings.warn(
# 0 data are loaded
# ...

# %%
# %%writefile /content/check_cfg.py
from mmengine import Config
cfg = Config.fromfile("/content/CLRerNet/configs/clrernet/culane/clrernet_culane_dla34_ema.py")

print("=== test pipeline ===")
for step in cfg.test_dataloader.dataset.pipeline:
    print(step)

print("\n=== test_cfg ===")
print(cfg.model.bbox_head.test_cfg)
# Out:
# Writing /content/check_cfg.py

# %%
import os
os.environ["PYTHONPATH"] = "/content/CLRerNet"
# !/usr/local/envs/clrernet/bin/python /content/check_cfg.py
# Out:
# /usr/local/envs/clrernet/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.24). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# === test pipeline ===
# {'type': 'albumentation', 'pipelines': [{'type': 'Compose', 'params': {'bboxes': False, 'keypoints': True, 'masks': True}}, {'type': 'Crop', 'x_min': 0, 'x_max': 1640, 'y_min': 270, 'y_max': 590, 'p': 1}, {'type': 'Resize', 'height': 320, 'width': 800, 'p': 1}]}
# {'type': 'PackCLRNetInputs', 'meta_keys': ['filename', 'sub_img_name', 'ori_shape', 'img_shape']}
#
# === test_cfg ===
# Traceback (most recent call last):
#   File "/usr/local/envs/clrernet/lib/python3.10/site-packages/mmengine/config/config.py", line 109, in __getattr__
#     value = super().__getattr__(name)
# ...

# %%
# %%writefile /content/CLRerNet/demo/video_demo.py
from argparse import ArgumentParser

import cv2
import torch
from mmdet.apis import init_detector

from libs.datasets.metrics.culane_metric import interp
from libs.datasets.pipelines import Compose
from libs.utils.visualizer import visualize_lanes

CULANE_W, CULANE_H = 1640, 590


def parse_args():
    parser = ArgumentParser()
    parser.add_argument('video', help='Input video file')
    parser.add_argument('config', help='Config file')
    parser.add_argument('checkpoint', help='Checkpoint file')
    parser.add_argument('--out-file', default='result.mp4', help='Path to output video')
    parser.add_argument('--device', default='cuda:0', help='Device used for inference')
    parser.add_argument('--max-frames', type=int, default=0, help='Limit frames for quick testing (0 = no limit)')
    return parser.parse_args()


def get_prediction(lanes, ori_h, ori_w):
    preds = []
    for lane in lanes:
        lane = lane.cpu().numpy()
        xs = lane[:, 0]
        ys = lane[:, 1]
        valid_mask = (xs >= 0) & (xs < 1)
        xs = xs * ori_w
        lane_xs = xs[valid_mask]
        lane_ys = ys[valid_mask] * ori_h
        lane_xs, lane_ys = lane_xs[::-1], lane_ys[::-1]
        pred = [(x, y) for x, y in zip(lane_xs, lane_ys)]
        interp_pred = interp(pred, n=5)
        preds.append(interp_pred)
    return preds


def inference_one_frame(model, img, test_pipeline):
    ori_shape = img.shape
    data = dict(
        filename=None,
        sub_img_name=None,
        img=img,
        gt_points=[],
        id_classes=[],
        id_instances=[],
        img_shape=ori_shape,
        ori_shape=ori_shape,
    )
    data = test_pipeline(data)
    data_ = dict(
        inputs=[data["inputs"]],
        data_samples=[data["data_samples"]],
    )
    with torch.no_grad():
        results = model.test_step(data_)
    lanes = results[0]['lanes']
    preds = get_prediction(lanes, ori_shape[0], ori_shape[1])
    return preds


def main(args):
    model = init_detector(args.config, args.checkpoint, device=args.device)
    model.bbox_head.test_cfg.as_lanes = False
    cfg = model.cfg
    test_pipeline = Compose(cfg.test_dataloader.dataset.pipeline)

    cap = cv2.VideoCapture(args.video)
    if not cap.isOpened():
        raise RuntimeError(f"Could not open video: {args.video}")

    fps = cap.get(cv2.CAP_PROP_FPS) or 25
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"Resizing every frame to {CULANE_W}x{CULANE_H} to match CULane training resolution")

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    writer = cv2.VideoWriter(args.out_file, fourcc, fps, (CULANE_W, CULANE_H))

    frame_idx = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frame = cv2.resize(frame, (CULANE_W, CULANE_H))
        preds = inference_one_frame(model, frame, test_pipeline)
        if frame_idx < 5:
            print(f"Frame {frame_idx}: {len(preds)} lanes detected")
        vis = visualize_lanes(frame, preds)
        writer.write(vis)
        frame_idx += 1
        if args.max_frames and frame_idx >= args.max_frames:
            break
        if frame_idx % 20 == 0:
            print(f"Processed {frame_idx}/{total_frames} frames")

    cap.release()
    writer.release()
    print(f"Done. Saved to {args.out_file}")


if __name__ == '__main__':
    args = parse_args()
    main(args)
# Out:
# Overwriting /content/CLRerNet/demo/video_demo.py

# %%
import os
os.environ["MPLBACKEND"] = "Agg"
os.environ["PYTHONPATH"] = "/content/CLRerNet"

# !/usr/local/envs/clrernet/bin/python /content/CLRerNet/demo/video_demo.py /content/your_video.mp4 /content/CLRerNet/configs/clrernet/culane/clrernet_culane_dla34_ema.py /content/CLRerNet/clrernet_culane_dla34_ema.pth --out-file=/content/CLRerNet/result_test.mp4 --max-frames 10
# Out:
# /usr/local/envs/clrernet/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.24). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loads checkpoint by local backend from path: /content/CLRerNet/clrernet_culane_dla34_ema.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: bbox_head.loss_seg.criterion.weight, bbox_head.seg_decoder.conv.weight, bbox_head.seg_decoder.conv.bias
#
# /usr/local/envs/clrernet/lib/python3.10/site-packages/mmdet/apis/inference.py:90: UserWarning: dataset_meta or class names are not saved in the checkpoint's meta data, use COCO classes by default.
#   warnings.warn(
# 0 data are loaded
# ...

# %%
# %%writefile /content/check_crop.py
import cv2

CULANE_W, CULANE_H = 1640, 590
target_ratio = CULANE_W / CULANE_H  # ~2.78

cap = cv2.VideoCapture("/content/your_video.mp4")
ret, frame = cap.read()
cap.release()
h, w = frame.shape[:2]
print(f"Source frame: {w}x{h}")

crop_h = int(w / target_ratio)

# exclude the hood: adjust this fraction until the hood mostly disappears
bottom_margin_frac = 0.22   # try 0.18, 0.22, 0.26 etc.
bottom_margin_px = int(h * bottom_margin_frac)

y_end = h - bottom_margin_px
y_start = y_end - crop_h
y_start = max(0, y_start)  # safety clamp

print(f"crop_h={crop_h}, y_start={y_start}, y_end={y_end}")

cropped = frame[y_start:y_end, 0:w]
resized = cv2.resize(cropped, (CULANE_W, CULANE_H))

cv2.imwrite("/content/debug_crop.png", resized)
print("Saved /content/debug_crop.png")
# Out:
# Overwriting /content/check_crop.py

# %%
# !/usr/local/envs/clrernet/bin/python /content/check_crop.py
# Out:
# Source frame: 3840x2160
# crop_h=1381, y_start=304, y_end=1685
# Saved /content/debug_crop.png

# %%
from PIL import Image
Image.open("/content/debug_crop.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1640x590>

# %%
# %%writefile /content/CLRerNet/demo/video_demo.py
from argparse import ArgumentParser

import cv2
import torch
from mmdet.apis import init_detector

from libs.datasets.metrics.culane_metric import interp
from libs.datasets.pipelines import Compose
from libs.utils.visualizer import visualize_lanes

CULANE_W, CULANE_H = 1640, 590
TARGET_RATIO = CULANE_W / CULANE_H
BOTTOM_MARGIN_FRAC = 0.22


def parse_args():
    parser = ArgumentParser()
    parser.add_argument('video', help='Input video file')
    parser.add_argument('config', help='Config file')
    parser.add_argument('checkpoint', help='Checkpoint file')
    parser.add_argument('--out-file', default='result.mp4', help='Path to output video')
    parser.add_argument('--device', default='cuda:0', help='Device used for inference')
    parser.add_argument('--max-frames', type=int, default=0, help='Limit frames for quick testing (0 = no limit)')
    return parser.parse_args()


def get_prediction(lanes, ori_h, ori_w):
    preds = []
    for lane in lanes:
        lane = lane.cpu().numpy()
        xs = lane[:, 0]
        ys = lane[:, 1]
        valid_mask = (xs >= 0) & (xs < 1)
        xs = xs * ori_w
        lane_xs = xs[valid_mask]
        lane_ys = ys[valid_mask] * ori_h
        lane_xs, lane_ys = lane_xs[::-1], lane_ys[::-1]
        pred = [(x, y) for x, y in zip(lane_xs, lane_ys)]
        interp_pred = interp(pred, n=5)
        preds.append(interp_pred)
    return preds


def crop_to_culane(frame):
    h, w = frame.shape[:2]
    crop_h = int(w / TARGET_RATIO)
    bottom_margin_px = int(h * BOTTOM_MARGIN_FRAC)
    y_end = h - bottom_margin_px
    y_start = max(0, y_end - crop_h)
    cropped = frame[y_start:y_end, 0:w]
    return cv2.resize(cropped, (CULANE_W, CULANE_H))


def inference_one_frame(model, img, test_pipeline):
    ori_shape = img.shape
    data = dict(
        filename=None,
        sub_img_name=None,
        img=img,
        gt_points=[],
        id_classes=[],
        id_instances=[],
        img_shape=ori_shape,
        ori_shape=ori_shape,
    )
    data = test_pipeline(data)
    data_ = dict(
        inputs=[data["inputs"]],
        data_samples=[data["data_samples"]],
    )
    with torch.no_grad():
        results = model.test_step(data_)
    lanes = results[0]['lanes']
    preds = get_prediction(lanes, ori_shape[0], ori_shape[1])
    return preds


def main(args):
    model = init_detector(args.config, args.checkpoint, device=args.device)
    model.bbox_head.test_cfg.as_lanes = False
    cfg = model.cfg
    test_pipeline = Compose(cfg.test_dataloader.dataset.pipeline)

    cap = cv2.VideoCapture(args.video)
    if not cap.isOpened():
        raise RuntimeError(f"Could not open video: {args.video}")

    fps = cap.get(cv2.CAP_PROP_FPS) or 25
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"Cropping+resizing every frame to {CULANE_W}x{CULANE_H} (CULane framing)")

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    writer = cv2.VideoWriter(args.out_file, fourcc, fps, (CULANE_W, CULANE_H))

    frame_idx = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frame = crop_to_culane(frame)
        preds = inference_one_frame(model, frame, test_pipeline)
        if frame_idx < 5:
            print(f"Frame {frame_idx}: {len(preds)} lanes detected")
        vis = visualize_lanes(frame, preds)
        writer.write(vis)
        frame_idx += 1
        if args.max_frames and frame_idx >= args.max_frames:
            break
        if frame_idx % 20 == 0:
            print(f"Processed {frame_idx}/{total_frames} frames")

    cap.release()
    writer.release()
    print(f"Done. Saved to {args.out_file}")


if __name__ == '__main__':
    args = parse_args()
    main(args)
# Out:
# Overwriting /content/CLRerNet/demo/video_demo.py

# %%
import os
os.environ["MPLBACKEND"] = "Agg"
os.environ["PYTHONPATH"] = "/content/CLRerNet"

# !/usr/local/envs/clrernet/bin/python /content/CLRerNet/demo/video_demo.py /content/your_video.mp4 /content/CLRerNet/configs/clrernet/culane/clrernet_culane_dla34_ema.py /content/CLRerNet/clrernet_culane_dla34_ema.pth --out-file=/content/CLRerNet/result_test.mp4 --max-frames 240
# Out:
# /usr/local/envs/clrernet/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.24). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loads checkpoint by local backend from path: /content/CLRerNet/clrernet_culane_dla34_ema.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: bbox_head.loss_seg.criterion.weight, bbox_head.seg_decoder.conv.weight, bbox_head.seg_decoder.conv.bias
#
# /usr/local/envs/clrernet/lib/python3.10/site-packages/mmdet/apis/inference.py:90: UserWarning: dataset_meta or class names are not saved in the checkpoint's meta data, use COCO classes by default.
#   warnings.warn(
# 0 data are loaded
# ...

# %%
# %%writefile /content/check_testcfg.py
from mmdet.apis import init_detector

model = init_detector(
    "/content/CLRerNet/configs/clrernet/culane/clrernet_culane_dla34_ema.py",
    "/content/CLRerNet/clrernet_culane_dla34_ema.pth",
    device="cuda:0",
)
print(model.bbox_head.test_cfg)
# Out:
# Writing /content/check_testcfg.py

# %%
# !/usr/local/envs/clrernet/bin/python /content/check_testcfg.py
# Out:
# /usr/local/envs/clrernet/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.24). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loads checkpoint by local backend from path: /content/CLRerNet/clrernet_culane_dla34_ema.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: bbox_head.loss_seg.criterion.weight, bbox_head.seg_decoder.conv.weight, bbox_head.seg_decoder.conv.bias
#
# /usr/local/envs/clrernet/lib/python3.10/site-packages/mmdet/apis/inference.py:90: UserWarning: dataset_meta or class names are not saved in the checkpoint's meta data, use COCO classes by default.
#   warnings.warn(
# 0 data are loaded
# ...

# %%
# %%writefile /content/CLRerNet/demo/video_demo.py
from argparse import ArgumentParser

import cv2
import torch
from mmdet.apis import init_detector

from libs.datasets.metrics.culane_metric import interp
from libs.datasets.pipelines import Compose
from libs.utils.visualizer import visualize_lanes

CULANE_W, CULANE_H = 1640, 590
TARGET_RATIO = CULANE_W / CULANE_H
BOTTOM_MARGIN_FRAC = 0.22


def parse_args():
    parser = ArgumentParser()
    parser.add_argument('video', help='Input video file')
    parser.add_argument('config', help='Config file')
    parser.add_argument('checkpoint', help='Checkpoint file')
    parser.add_argument('--out-file', default='result.mp4', help='Path to output video')
    parser.add_argument('--device', default='cuda:0', help='Device used for inference')
    parser.add_argument('--max-frames', type=int, default=0, help='Limit frames for quick testing (0 = no limit)')
    parser.add_argument('--conf-threshold', type=float, default=0.43, help='Lane confidence threshold')
    return parser.parse_args()


def get_prediction(lanes, ori_h, ori_w):
    preds = []
    for lane in lanes:
        lane = lane.cpu().numpy()
        xs = lane[:, 0]
        ys = lane[:, 1]
        valid_mask = (xs >= 0) & (xs < 1)
        xs = xs * ori_w
        lane_xs = xs[valid_mask]
        lane_ys = ys[valid_mask] * ori_h
        lane_xs, lane_ys = lane_xs[::-1], lane_ys[::-1]
        pred = [(x, y) for x, y in zip(lane_xs, lane_ys)]
        interp_pred = interp(pred, n=5)
        preds.append(interp_pred)
    return preds


def crop_to_culane(frame):
    h, w = frame.shape[:2]
    crop_h = int(w / TARGET_RATIO)
    bottom_margin_px = int(h * BOTTOM_MARGIN_FRAC)
    y_end = h - bottom_margin_px
    y_start = max(0, y_end - crop_h)
    cropped = frame[y_start:y_end, 0:w]
    return cv2.resize(cropped, (CULANE_W, CULANE_H))


def inference_one_frame(model, img, test_pipeline):
    ori_shape = img.shape
    data = dict(
        filename=None,
        sub_img_name=None,
        img=img,
        gt_points=[],
        id_classes=[],
        id_instances=[],
        img_shape=ori_shape,
        ori_shape=ori_shape,
    )
    data = test_pipeline(data)
    data_ = dict(
        inputs=[data["inputs"]],
        data_samples=[data["data_samples"]],
    )
    with torch.no_grad():
        results = model.test_step(data_)
    lanes = results[0]['lanes']
    preds = get_prediction(lanes, ori_shape[0], ori_shape[1])
    return preds


def main(args):
    model = init_detector(args.config, args.checkpoint, device=args.device)
    model.bbox_head.test_cfg.as_lanes = False
    model.bbox_head.test_cfg.conf_threshold = args.conf_threshold
    print(f"Using conf_threshold={args.conf_threshold}")
    cfg = model.cfg
    test_pipeline = Compose(cfg.test_dataloader.dataset.pipeline)

    cap = cv2.VideoCapture(args.video)
    if not cap.isOpened():
        raise RuntimeError(f"Could not open video: {args.video}")

    fps = cap.get(cv2.CAP_PROP_FPS) or 25
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    writer = cv2.VideoWriter(args.out_file, fourcc, fps, (CULANE_W, CULANE_H))

    frame_idx = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frame = crop_to_culane(frame)
        preds = inference_one_frame(model, frame, test_pipeline)
        if frame_idx < 10:
            print(f"Frame {frame_idx}: {len(preds)} lanes detected")
        vis = visualize_lanes(frame, preds)
        writer.write(vis)
        frame_idx += 1
        if args.max_frames and frame_idx >= args.max_frames:
            break
        if frame_idx % 20 == 0:
            print(f"Processed {frame_idx}/{total_frames} frames")

    cap.release()
    writer.release()
    print(f"Done. Saved to {args.out_file}")


if __name__ == '__main__':
    args = parse_args()
    main(args)
# Out:
# Overwriting /content/CLRerNet/demo/video_demo.py

# %%
import os
os.environ["MPLBACKEND"] = "Agg"
os.environ["PYTHONPATH"] = "/content/CLRerNet"

# !/usr/local/envs/clrernet/bin/python /content/CLRerNet/demo/video_demo.py /content/your_video.mp4 /content/CLRerNet/configs/clrernet/culane/clrernet_culane_dla34_ema.py /content/CLRerNet/clrernet_culane_dla34_ema.pth --out-file=/content/CLRerNet/result_test.mp4 --conf-threshold 0.25
# Out:
# /usr/local/envs/clrernet/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.24). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loads checkpoint by local backend from path: /content/CLRerNet/clrernet_culane_dla34_ema.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: bbox_head.loss_seg.criterion.weight, bbox_head.seg_decoder.conv.weight, bbox_head.seg_decoder.conv.bias
#
# /usr/local/envs/clrernet/lib/python3.10/site-packages/mmdet/apis/inference.py:90: UserWarning: dataset_meta or class names are not saved in the checkpoint's meta data, use COCO classes by default.
#   warnings.warn(
# 0 data are loaded
# ...

# %%
# %%writefile /content/debug_lane_extent.py
import cv2
import torch
from mmdet.apis import init_detector
from libs.datasets.pipelines import Compose

model = init_detector(
    "/content/CLRerNet/configs/clrernet/culane/clrernet_culane_dla34_ema.py",
    "/content/CLRerNet/clrernet_culane_dla34_ema.pth",
    device="cuda:0",
)
model.bbox_head.test_cfg.as_lanes = False
model.bbox_head.test_cfg.conf_threshold = 0.25
cfg = model.cfg
test_pipeline = Compose(cfg.test_dataloader.dataset.pipeline)

CULANE_W, CULANE_H = 1640, 590
TARGET_RATIO = CULANE_W / CULANE_H
BOTTOM_MARGIN_FRAC = 0.22

cap = cv2.VideoCapture("/content/your_video.mp4")
# jump to frame 100, well into the highway driving shown in your screenshot
cap.set(cv2.CAP_PROP_POS_FRAMES, 100)
ret, frame = cap.read()
cap.release()
assert ret, "Could not read frame 100"

h, w = frame.shape[:2]
crop_h = int(w / TARGET_RATIO)
bottom_margin_px = int(h * BOTTOM_MARGIN_FRAC)
y_end = h - bottom_margin_px
y_start = max(0, y_end - crop_h)
cropped = frame[y_start:y_end, 0:w]
frame = cv2.resize(cropped, (CULANE_W, CULANE_H))

ori_shape = frame.shape
data = dict(
    filename=None, sub_img_name=None, img=frame, gt_points=[],
    id_classes=[], id_instances=[], img_shape=ori_shape, ori_shape=ori_shape,
)
data = test_pipeline(data)
data_ = dict(inputs=[data["inputs"]], data_samples=[data["data_samples"]])

with torch.no_grad():
    results = model.test_step(data_)

lanes = results[0]['lanes']
print(f"{len(lanes)} lanes")
for i, lane in enumerate(lanes):
    lane = lane.cpu().numpy()
    xs, ys = lane[:, 0], lane[:, 1]
    print(f"lane {i}: {len(lane)} raw points, y range {ys.min():.3f}-{ys.max():.3f} (normalized), x range {xs.min():.3f}-{xs.max():.3f}")
# Out:
# Overwriting /content/debug_lane_extent.py

# %%
# !/usr/local/envs/clrernet/bin/python /content/debug_lane_extent.py
# Out:
# /usr/local/envs/clrernet/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.24). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loads checkpoint by local backend from path: /content/CLRerNet/clrernet_culane_dla34_ema.pth
# The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: bbox_head.loss_seg.criterion.weight, bbox_head.seg_decoder.conv.weight, bbox_head.seg_decoder.conv.bias
#
# /usr/local/envs/clrernet/lib/python3.10/site-packages/mmdet/apis/inference.py:90: UserWarning: dataset_meta or class names are not saved in the checkpoint's meta data, use COCO classes by default.
#   warnings.warn(
# 0 data are loaded
# ...
